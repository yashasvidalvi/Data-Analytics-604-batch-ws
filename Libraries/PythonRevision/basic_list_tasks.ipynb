# %%
numbers = [12,45,7,23,45,89,12,34,5,67]
print(numbers)
# Out:
# [12, 45, 7, 23, 45, 89, 12, 34, 5, 67]

# %%
print(numbers[0],numbers[-1])
# Out:
# 12 67

# %%
print(len(numbers))
# Out:
# 10

# %%
print(sum(numbers))
# Out:
# 339

# %%
print(max(numbers))
print(min(numbers))
# Out:
# 89
# 5

# %%
for num in numbers:
    if num%2==0:
        print(num)
# Out:
# 12
# 12
# 34

# %%
for num in numbers:
    if num%2!=0:
        print(num)
# Out:
# 45
# 7
# 23
# 45
# 89
# 5
# 67

# %%
even_count = 0
odd_count = 0

for num in numbers:
    if num%2==0:
        even_count +=1
    else:
        odd_count +=1
print(even_count)
print(odd_count)
# Out:
# 3
# 7

# %%
if 23 in numbers:
    print("23 exists")
else:
    print("23 doesnt exists")
# Out:
# 23 exists

# %%
print(numbers.index(89))
# Out:
# 5

# %%
s = numbers.append(100)
print(numbers)
# Out:
# [12, 45, 7, 23, 45, 89, 12, 34, 5, 67, 100, 100, 5]

# %%
numbers.insert(3,50)
print(numbers)
# Out:
# [12, 45, 7, 50, 23, 45, 89, 12, 34, 5, 67, 100, 100, 5]

# %%
numbers.remove(45)
print(numbers)
# Out:
# [12, 7, 50, 23, 45, 89, 12, 34, 5, 67, 100, 100, 5]

# %%
d = list(set(numbers))
print(d)
# Out:
# [34, 67, 100, 5, 7, 12, 45, 50, 23, 89]

# %%
numbers.sort()
print(numbers)

numbers.sort(reverse=True)
print(numbers)
# Out:
# [5, 5, 7, 12, 12, 23, 34, 45, 50, 67, 89, 100, 100]
# [100, 100, 89, 67, 50, 45, 34, 23, 12, 12, 7, 5, 5]
