# %%
import pandas  as pd
import seaborn as sns

# %%
df = pd.read_csv("sales.csv")
df
# Out:
#     id  month       branch          course  sales_amount
# 0    1    jan  karve nagar    data science        300000
# 1    2    jan  karve nagar  data analytics        200000
# 2    3    jan        warje    data science        400000
# 3    4    jan        warje  data analytics        500000
# 4    6    feb  karve nagar  data analytics        400000
# 5    7    feb        warje    data science        600000
# 6    8    feb        warje  data analytics        100000
# 7    9  March  karve nagar    data science        450000
# 8   11  March        warje    data science        650000
# 9   12  March        warje  data analytics        170000
# 10  13  March        warje  data analytics        170000
# 11  14  March  karve nagar    data science        600000
# 12  15  March        warje  data analytics        160000
# 13  16    feb  karve nagar    data science        700000
# 14  17    feb  karve nagar  data analytics         50000
# ...

# %%
sns.countplot(data=df,x="branch",hue="course")
# Out:
# <Axes: xlabel='branch', ylabel='count'>

# %%
study_df = pd.read_csv("study_analysis.csv")
study_df
# Out:
#    roll  gender  study_hours  marks
# 0     1    male            1     30
# 1     2  female            1     40
# 2     3    male            2     45
# 3     4  female            3     55
# 4     5    male            4     60
# 5     6    male            5     70
# 6     7  female            6     75
# 7     8    male            7     80
# 8     9  female            8     90

# %%
sns.scatterplot(data=study_df,x = "study_hours",y = "marks",hue="gender",style = "gender",size="marks")
# Out:
# <Axes: xlabel='study_hours', ylabel='marks'>

# %%
sns.boxplot(data=study_df,y="marks")
# Out:
# <Axes: ylabel='marks'>
