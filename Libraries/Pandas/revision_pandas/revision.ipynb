# %%
import pandas as pd

# %%
student_admission_df = pd.read_excel("student_admission.xlsx")
student_admission_df
# Out:
#   Student_ID Student_Name       Branch             Course Admission_Date  \
# 0       S101         Amit    Chinchwad     Data Analytics     2026-01-10
# 1       S102        Sneha     Hadapsar       Data Science     2026-01-12
# 2       S103        Rohit  Karve Nagar  Python Full Stack     2026-01-15
# 3       S104        Pooja    Chinchwad     Data Analytics     2026-01-18
# 4       S105        Akash       Nagpur    Java Full Stack     2026-01-20
# 5       S106         Neha     Hadapsar            Testing     2026-01-22
# 6       S107        Rahul    Chinchwad       Data Science     2026-01-25
# 7       S108       Snehal  Karve Nagar  Python Full Stack     2026-02-02
# 8       S109        Kunal       Nagpur     Data Analytics     2026-02-05
# 9       S110     Priyanka     Hadapsar       Data Science     2026-02-08
#
#   Counselor
# 0     Rahul
# 1     Priya
# 2      Amit
# 3     Rahul
# 4      Neha
# 5     Priya
# 6      Amit
# 7      Neha
# 8     Rahul
# 9     Priya

# %%
student_payment_df = pd.read_excel("student_payment.xlsx")
student_payment_df
# Out:
#   Student_ID  Total_Fees  Paid_Fees Payment_Mode
# 0       S101       40000      30000          UPI
# 1       S102       50000      50000         Cash
# 2       S103       30000      20000          UPI
# 3       S104       40000      40000         Card
# 4       S105       30000      15000          UPI
# 5       S106       25000      25000         Cash
# 6       S107       50000      30000         Card
# 7       S108       30000      30000          UPI
# 8       S109       40000      25000         Cash
# 9       S110       50000      35000          UPI

# %%
student_payment_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Student_ID    10 non-null     str
#  1   Total_Fees    10 non-null     int64
#  2   Paid_Fees     10 non-null     int64
#  3   Payment_Mode  10 non-null     str
# dtypes: int64(2), str(2)
# memory usage: 452.0 bytes

# %%
# no of rowa
# len(student_payment_df)
len(student_admission_df)
# Out:
# 10

# %%
# no of columns
# len(student_admission_df.columns)
len(student_payment_df.columns)
# Out:
# 4

# %%
#Column names
# student_admission_df.columns
student_payment_df.columns
# Out:
# Index(['Student_ID', 'Total_Fees', 'Paid_Fees', 'Payment_Mode'], dtype='str')

# %%
#datatypes
student_payment_df.dtypes
student_admission_df.dtypes
# Out:
# Student_ID        str
# Student_Name      str
# Branch            str
# Course            str
# Admission_Date    str
# Counselor         str
# dtype: object

# %%
#merge
admission_df = pd.merge(student_admission_df,student_payment_df,how = "inner",on = "Student_ID")
admission_df
# Out:
#   Student_ID Student_Name       Branch             Course Admission_Date  \
# 0       S101         Amit    Chinchwad     Data Analytics     2026-01-10
# 1       S102        Sneha     Hadapsar       Data Science     2026-01-12
# 2       S103        Rohit  Karve Nagar  Python Full Stack     2026-01-15
# 3       S104        Pooja    Chinchwad     Data Analytics     2026-01-18
# 4       S105        Akash       Nagpur    Java Full Stack     2026-01-20
# 5       S106         Neha     Hadapsar            Testing     2026-01-22
# 6       S107        Rahul    Chinchwad       Data Science     2026-01-25
# 7       S108       Snehal  Karve Nagar  Python Full Stack     2026-02-02
# 8       S109        Kunal       Nagpur     Data Analytics     2026-02-05
# 9       S110     Priyanka     Hadapsar       Data Science     2026-02-08
#
#   Counselor  Total_Fees  Paid_Fees Payment_Mode
# 0     Rahul       40000      30000          UPI
# 1     Priya       50000      50000         Cash
# ...

# %%
admission_df.head(1)
# Out:
#   Student_ID Student_Name     Branch          Course Admission_Date Counselor  \
# 0       S101         Amit  Chinchwad  Data Analytics     2026-01-10     Rahul
#
#    Total_Fees  Paid_Fees Payment_Mode
# 0       40000      30000          UPI

# %%
admission_df.iloc[0]
# Out:
# Student_ID                  S101
# Student_Name                Amit
# Branch                 Chinchwad
# Course            Data Analytics
# Admission_Date        2026-01-10
# Counselor                  Rahul
# Total_Fees                 40000
# Paid_Fees                  30000
# Payment_Mode                 UPI
# Name: 0, dtype: object

# %%
admission_df.iloc[-1]
# Out:
# Student_ID                S110
# Student_Name          Priyanka
# Branch                Hadapsar
# Course            Data Science
# Admission_Date      2026-02-08
# Counselor                Priya
# Total_Fees               50000
# Paid_Fees                35000
# Payment_Mode               UPI
# Name: 9, dtype: object

# %%
admission_df.head()
# Out:
#   Student_ID Student_Name       Branch             Course Admission_Date  \
# 0       S101         Amit    Chinchwad     Data Analytics     2026-01-10
# 1       S102        Sneha     Hadapsar       Data Science     2026-01-12
# 2       S103        Rohit  Karve Nagar  Python Full Stack     2026-01-15
# 3       S104        Pooja    Chinchwad     Data Analytics     2026-01-18
# 4       S105        Akash       Nagpur    Java Full Stack     2026-01-20
#
#   Counselor  Total_Fees  Paid_Fees Payment_Mode
# 0     Rahul       40000      30000          UPI
# 1     Priya       50000      50000         Cash
# 2      Amit       30000      20000          UPI
# 3     Rahul       40000      40000         Card
# 4      Neha       30000      15000          UPI

# %%
admission_df.iloc[2:7]
# Out:
#   Student_ID Student_Name       Branch             Course Admission_Date  \
# 2       S103        Rohit  Karve Nagar  Python Full Stack     2026-01-15
# 3       S104        Pooja    Chinchwad     Data Analytics     2026-01-18
# 4       S105        Akash       Nagpur    Java Full Stack     2026-01-20
# 5       S106         Neha     Hadapsar            Testing     2026-01-22
# 6       S107        Rahul    Chinchwad       Data Science     2026-01-25
#
#   Counselor  Total_Fees  Paid_Fees Payment_Mode
# 2      Amit       30000      20000          UPI
# 3     Rahul       40000      40000         Card
# 4      Neha       30000      15000          UPI
# 5     Priya       25000      25000         Cash
# 6      Amit       50000      30000         Card

# %%
admission_df[admission_df["Student_ID"]=='S105']
# Out:
#   Student_ID Student_Name  Branch           Course Admission_Date Counselor  \
# 4       S105        Akash  Nagpur  Java Full Stack     2026-01-20      Neha
#
#    Total_Fees  Paid_Fees Payment_Mode
# 4       30000      15000          UPI

# %%
admission_df[admission_df["Branch"]=="Chinchwad"]
# Out:
#   Student_ID Student_Name     Branch          Course Admission_Date Counselor  \
# 0       S101         Amit  Chinchwad  Data Analytics     2026-01-10     Rahul
# 3       S104        Pooja  Chinchwad  Data Analytics     2026-01-18     Rahul
# 6       S107        Rahul  Chinchwad    Data Science     2026-01-25      Amit
#
#    Total_Fees  Paid_Fees Payment_Mode
# 0       40000      30000          UPI
# 3       40000      40000         Card
# 6       50000      30000         Card

# %%
admission_df["Student_Name"]
# Out:
# 0        Amit
# 1       Sneha
# 2       Rohit
# 3       Pooja
# 4       Akash
# 5        Neha
# 6       Rahul
# 7      Snehal
# 8       Kunal
# 9    Priyanka
# Name: Student_Name, dtype: str

# %%
admission_df["Course"]
# Out:
# 0       Data Analytics
# 1         Data Science
# 2    Python Full Stack
# 3       Data Analytics
# 4      Java Full Stack
# 5              Testing
# 6         Data Science
# 7    Python Full Stack
# 8       Data Analytics
# 9         Data Science
# Name: Course, dtype: str

# %%
admission_df[["Student_Name","Branch","Course","Paid_Fees"]]
# Out:
#   Student_Name       Branch             Course  Paid_Fees
# 0         Amit    Chinchwad     Data Analytics      30000
# 1        Sneha     Hadapsar       Data Science      50000
# 2        Rohit  Karve Nagar  Python Full Stack      20000
# 3        Pooja    Chinchwad     Data Analytics      40000
# 4        Akash       Nagpur    Java Full Stack      15000
# 5         Neha     Hadapsar            Testing      25000
# 6        Rahul    Chinchwad       Data Science      30000
# 7       Snehal  Karve Nagar  Python Full Stack      30000
# 8        Kunal       Nagpur     Data Analytics      25000
# 9     Priyanka     Hadapsar       Data Science      35000

# %%
admission_df.drop(columns = ["Payment_Mode"])
# Out:
#   Student_ID Student_Name       Branch             Course Admission_Date  \
# 0       S101         Amit    Chinchwad     Data Analytics     2026-01-10
# 1       S102        Sneha     Hadapsar       Data Science     2026-01-12
# 2       S103        Rohit  Karve Nagar  Python Full Stack     2026-01-15
# 3       S104        Pooja    Chinchwad     Data Analytics     2026-01-18
# 4       S105        Akash       Nagpur    Java Full Stack     2026-01-20
# 5       S106         Neha     Hadapsar            Testing     2026-01-22
# 6       S107        Rahul    Chinchwad       Data Science     2026-01-25
# 7       S108       Snehal  Karve Nagar  Python Full Stack     2026-02-02
# 8       S109        Kunal       Nagpur     Data Analytics     2026-02-05
# 9       S110     Priyanka     Hadapsar       Data Science     2026-02-08
#
#   Counselor  Total_Fees  Paid_Fees
# 0     Rahul       40000      30000
# 1     Priya       50000      50000
# 2      Amit       30000      20000
# ...

# %%
admission_df["Remaining_Fees"] = admission_df["Total_Fees"]-admission_df["Paid_Fees"]

# %%
admission_df
# Out:
#   Student_ID Student_Name       Branch             Course Admission_Date  \
# 0       S101         Amit    Chinchwad     Data Analytics     2026-01-10
# 1       S102        Sneha     Hadapsar       Data Science     2026-01-12
# 2       S103        Rohit  Karve Nagar  Python Full Stack     2026-01-15
# 3       S104        Pooja    Chinchwad     Data Analytics     2026-01-18
# 4       S105        Akash       Nagpur    Java Full Stack     2026-01-20
# 5       S106         Neha     Hadapsar            Testing     2026-01-22
# 6       S107        Rahul    Chinchwad       Data Science     2026-01-25
# 7       S108       Snehal  Karve Nagar  Python Full Stack     2026-02-02
# 8       S109        Kunal       Nagpur     Data Analytics     2026-02-05
# 9       S110     Priyanka     Hadapsar       Data Science     2026-02-08
#
#   Counselor  Total_Fees  Paid_Fees Payment_Mode  Remaining_Fees
# 0     Rahul       40000      30000          UPI           10000
# ...

# %%
admission_df["Payment_Status"] = admission_df["Remaining_Fees"].apply(lambda x: "Fully Paid" if x==0 else "Pending")

# %%
admission_df
# Out:
#   Student_ID Student_Name       Branch             Course Admission_Date  \
# 0       S101         Amit    Chinchwad     Data Analytics     2026-01-10
# 1       S102        Sneha     Hadapsar       Data Science     2026-01-12
# 2       S103        Rohit  Karve Nagar  Python Full Stack     2026-01-15
# 3       S104        Pooja    Chinchwad     Data Analytics     2026-01-18
# 4       S105        Akash       Nagpur    Java Full Stack     2026-01-20
# 5       S106         Neha     Hadapsar            Testing     2026-01-22
# 6       S107        Rahul    Chinchwad       Data Science     2026-01-25
# 7       S108       Snehal  Karve Nagar  Python Full Stack     2026-02-02
# 8       S109        Kunal       Nagpur     Data Analytics     2026-02-05
# 9       S110     Priyanka     Hadapsar       Data Science     2026-02-08
#
#   Counselor  Total_Fees  Paid_Fees Payment_Mode  Remaining_Fees Payment_Status
# 0     Rahul       40000      30000          UPI           10000        Pending
# ...

# %%
admission_df.loc[len(admission_df)] = ["S111","Vaibhav","Chinchwad","Data Analytics","2026-02-10","Rahul",40000,20000,"UPI",20000,"Pending"]

# %%
admission_df
# Out:
#    Student_ID Student_Name       Branch             Course Admission_Date  \
# 0        S101         Amit    Chinchwad     Data Analytics     2026-01-10
# 1        S102        Sneha     Hadapsar       Data Science     2026-01-12
# 2        S103        Rohit  Karve Nagar  Python Full Stack     2026-01-15
# 3        S104        Pooja    Chinchwad     Data Analytics     2026-01-18
# 4        S105        Akash       Nagpur    Java Full Stack     2026-01-20
# 5        S106         Neha     Hadapsar            Testing     2026-01-22
# 6        S107        Rahul    Chinchwad       Data Science     2026-01-25
# 7        S108       Snehal  Karve Nagar  Python Full Stack     2026-02-02
# 8        S109        Kunal       Nagpur     Data Analytics     2026-02-05
# 9        S110     Priyanka     Hadapsar       Data Science     2026-02-08
# 10       S111      Vaibhav    Chinchwad     Data Analytics     2026-02-10
#
#    Counselor  Total_Fees  Paid_Fees Payment_Mode  Remaining_Fees  \
# ...

# %%
admission_df[admission_df['Student_ID']!='S105']
# Out:
#    Student_ID Student_Name       Branch             Course Admission_Date  \
# 0        S101         Amit    Chinchwad     Data Analytics     2026-01-10
# 1        S102        Sneha     Hadapsar       Data Science     2026-01-12
# 2        S103        Rohit  Karve Nagar  Python Full Stack     2026-01-15
# 3        S104        Pooja    Chinchwad     Data Analytics     2026-01-18
# 5        S106         Neha     Hadapsar            Testing     2026-01-22
# 6        S107        Rahul    Chinchwad       Data Science     2026-01-25
# 7        S108       Snehal  Karve Nagar  Python Full Stack     2026-02-02
# 8        S109        Kunal       Nagpur     Data Analytics     2026-02-05
# 9        S110     Priyanka     Hadapsar       Data Science     2026-02-08
# 10       S111      Vaibhav    Chinchwad     Data Analytics     2026-02-10
#
#    Counselor  Total_Fees  Paid_Fees Payment_Mode  Remaining_Fees  \
# 0      Rahul       40000      30000          UPI           10000
# ...

# %%
admission_df.drop(columns = ["Payment_Mode"])
# Out:
#    Student_ID Student_Name       Branch             Course Admission_Date  \
# 0        S101         Amit    Chinchwad     Data Analytics     2026-01-10
# 1        S102        Sneha     Hadapsar       Data Science     2026-01-12
# 2        S103        Rohit  Karve Nagar  Python Full Stack     2026-01-15
# 3        S104        Pooja    Chinchwad     Data Analytics     2026-01-18
# 4        S105        Akash       Nagpur    Java Full Stack     2026-01-20
# 5        S106         Neha     Hadapsar            Testing     2026-01-22
# 6        S107        Rahul    Chinchwad       Data Science     2026-01-25
# 7        S108       Snehal  Karve Nagar  Python Full Stack     2026-02-02
# 8        S109        Kunal       Nagpur     Data Analytics     2026-02-05
# 9        S110     Priyanka     Hadapsar       Data Science     2026-02-08
# 10       S111      Vaibhav    Chinchwad     Data Analytics     2026-02-10
#
#    Counselor  Total_Fees  Paid_Fees  Remaining_Fees Payment_Status
# ...

# %%
Total_Students = admission_df["Student_ID"].count()
Total_Students
# Out:
# np.int64(11)

# %%
len(admission_df)
# Out:
# 11

# %%
Total_Fees=admission_df["Total_Fees"].sum()
Total_Fees
# Out:
# np.int64(425000)

# %%
Total_Paid_Fees = admission_df["Paid_Fees"].sum()
Total_Paid_Fees
# Out:
# np.int64(320000)

# %%
Total_Remaining_Fees = admission_df["Remaining_Fees"].sum()
Total_Remaining_Fees
# Out:
# np.int64(105000)

# %%
Average_Fees = admission_df["Total_Fees"].mean()
Average_Fees
# Out:
# np.float64(38636.36363636364)

# %%
admission_df["Total_Fees"].max()
# Out:
# np.int64(50000)

# %%
admission_df["Total_Fees"].min()
# Out:
# np.int64(25000)

# %%
admission_df
# Out:
#    Student_ID Student_Name       Branch             Course Admission_Date  \
# 0        S101         Amit    Chinchwad     Data Analytics     2026-01-10
# 1        S102        Sneha     Hadapsar       Data Science     2026-01-12
# 2        S103        Rohit  Karve Nagar  Python Full Stack     2026-01-15
# 3        S104        Pooja    Chinchwad     Data Analytics     2026-01-18
# 4        S105        Akash       Nagpur    Java Full Stack     2026-01-20
# 5        S106         Neha     Hadapsar            Testing     2026-01-22
# 6        S107        Rahul    Chinchwad       Data Science     2026-01-25
# 7        S108       Snehal  Karve Nagar  Python Full Stack     2026-02-02
# 8        S109        Kunal       Nagpur     Data Analytics     2026-02-05
# 9        S110     Priyanka     Hadapsar       Data Science     2026-02-08
# 10       S111      Vaibhav    Chinchwad     Data Analytics     2026-02-10
#
#    Counselor  Total_Fees  Paid_Fees Payment_Mode  Remaining_Fees  \
# ...

# %%
ga = admission_df.groupby(by="Branch")
ga

# %%
ga["Paid_Fees"].sum()
# Out:
# Branch
# Chinchwad      120000
# Hadapsar       110000
# Karve Nagar     50000
# Nagpur          40000
# Name: Paid_Fees, dtype: int64

# %%
gb = admission_df.groupby(by="Course")
gb

# %%
gb["Paid_Fees"].sum()
# Out:
# Course
# Data Analytics       115000
# Data Science         115000
# Java Full Stack       15000
# Python Full Stack     50000
# Testing               25000
# Name: Paid_Fees, dtype: int64

# %%
group = admission_df.groupby(by="Branch")
group

# %%
group["Student_ID"].count()
# Out:
# Branch
# Chinchwad      4
# Hadapsar       3
# Karve Nagar    2
# Nagpur         2
# Name: Student_ID, dtype: int64

# %%
gc = admission_df.groupby(by="Course")
gc

# %%
gc["Student_ID"].count()
# Out:
# Course
# Data Analytics       4
# Data Science         3
# Java Full Stack      1
# Python Full Stack    2
# Testing              1
# Name: Student_ID, dtype: int64

# %%
gcc = admission_df.groupby(by="Counselor")
gcc

# %%
gcc["Paid_Fees"].sum()
# Out:
# Counselor
# Amit      50000
# Neha      45000
# Priya    110000
# Rahul    115000
# Name: Paid_Fees, dtype: int64

# %%
admission_df.sort_values(by="Paid_Fees",ascending=False)
# Out:
#    Student_ID Student_Name       Branch             Course Admission_Date  \
# 1        S102        Sneha     Hadapsar       Data Science     2026-01-12
# 3        S104        Pooja    Chinchwad     Data Analytics     2026-01-18
# 9        S110     Priyanka     Hadapsar       Data Science     2026-02-08
# 7        S108       Snehal  Karve Nagar  Python Full Stack     2026-02-02
# 0        S101         Amit    Chinchwad     Data Analytics     2026-01-10
# 6        S107        Rahul    Chinchwad       Data Science     2026-01-25
# 8        S109        Kunal       Nagpur     Data Analytics     2026-02-05
# 5        S106         Neha     Hadapsar            Testing     2026-01-22
# 2        S103        Rohit  Karve Nagar  Python Full Stack     2026-01-15
# 10       S111      Vaibhav    Chinchwad     Data Analytics     2026-02-10
# 4        S105        Akash       Nagpur    Java Full Stack     2026-01-20
#
#    Counselor  Total_Fees  Paid_Fees Payment_Mode  Remaining_Fees  \
# ...

# %%
admission_df.sort_values(by="Remaining_Fees", ascending=False)
# Out:
#    Student_ID Student_Name       Branch             Course Admission_Date  \
# 6        S107        Rahul    Chinchwad       Data Science     2026-01-25
# 10       S111      Vaibhav    Chinchwad     Data Analytics     2026-02-10
# 8        S109        Kunal       Nagpur     Data Analytics     2026-02-05
# 9        S110     Priyanka     Hadapsar       Data Science     2026-02-08
# 4        S105        Akash       Nagpur    Java Full Stack     2026-01-20
# 0        S101         Amit    Chinchwad     Data Analytics     2026-01-10
# 2        S103        Rohit  Karve Nagar  Python Full Stack     2026-01-15
# 1        S102        Sneha     Hadapsar       Data Science     2026-01-12
# 3        S104        Pooja    Chinchwad     Data Analytics     2026-01-18
# 5        S106         Neha     Hadapsar            Testing     2026-01-22
# 7        S108       Snehal  Karve Nagar  Python Full Stack     2026-02-02
#
#    Counselor  Total_Fees  Paid_Fees Payment_Mode  Remaining_Fees  \
# ...

# %%
admission_df.sort_values(by=["Branch","Paid_Fees"])
# Out:
#    Student_ID Student_Name       Branch             Course Admission_Date  \
# 10       S111      Vaibhav    Chinchwad     Data Analytics     2026-02-10
# 0        S101         Amit    Chinchwad     Data Analytics     2026-01-10
# 6        S107        Rahul    Chinchwad       Data Science     2026-01-25
# 3        S104        Pooja    Chinchwad     Data Analytics     2026-01-18
# 5        S106         Neha     Hadapsar            Testing     2026-01-22
# 9        S110     Priyanka     Hadapsar       Data Science     2026-02-08
# 1        S102        Sneha     Hadapsar       Data Science     2026-01-12
# 2        S103        Rohit  Karve Nagar  Python Full Stack     2026-01-15
# 7        S108       Snehal  Karve Nagar  Python Full Stack     2026-02-02
# 4        S105        Akash       Nagpur    Java Full Stack     2026-01-20
# 8        S109        Kunal       Nagpur     Data Analytics     2026-02-05
#
#    Counselor  Total_Fees  Paid_Fees Payment_Mode  Remaining_Fees  \
# ...

# %%
# admission_df["Branch"].unique()
len(admission_df["Branch"].unique())
# Out:
# 4

# %%
# admission_df["Course"].unique()
len(admission_df["Course"].unique())
# Out:
# 5

# %%
# admission_df["Counselor"].unique()
len(admission_df["Counselor"].unique())
# Out:
# 4

# %%
# admission_df["Payment_Mode"].unique()
len(admission_df["Payment_Mode"].unique())
# Out:
# 3

# %%
admission_df[admission_df["Paid_Fees"]>30000]
# Out:
#   Student_ID Student_Name     Branch          Course Admission_Date Counselor  \
# 1       S102        Sneha   Hadapsar    Data Science     2026-01-12     Priya
# 3       S104        Pooja  Chinchwad  Data Analytics     2026-01-18     Rahul
# 9       S110     Priyanka   Hadapsar    Data Science     2026-02-08     Priya
#
#    Total_Fees  Paid_Fees Payment_Mode  Remaining_Fees Payment_Status
# 1       50000      50000         Cash               0     Fully Paid
# 3       40000      40000         Card               0     Fully Paid
# 9       50000      35000          UPI           15000        Pending

# %%
admission_df[admission_df["Remaining_Fees"]>10000]
# Out:
#    Student_ID Student_Name     Branch           Course Admission_Date  \
# 4        S105        Akash     Nagpur  Java Full Stack     2026-01-20
# 6        S107        Rahul  Chinchwad     Data Science     2026-01-25
# 8        S109        Kunal     Nagpur   Data Analytics     2026-02-05
# 9        S110     Priyanka   Hadapsar     Data Science     2026-02-08
# 10       S111      Vaibhav  Chinchwad   Data Analytics     2026-02-10
#
#    Counselor  Total_Fees  Paid_Fees Payment_Mode  Remaining_Fees  \
# 4       Neha       30000      15000          UPI           15000
# 6       Amit       50000      30000         Card           20000
# 8      Rahul       40000      25000         Cash           15000
# 9      Priya       50000      35000          UPI           15000
# 10     Rahul       40000      20000          UPI           20000
#
#    Payment_Status
# 4         Pending
# 6         Pending
# 8         Pending
# 9         Pending
# 10        Pending

# %%
admission_df[admission_df["Course"] == "Data Science"]
# Out:
#   Student_ID Student_Name     Branch        Course Admission_Date Counselor  \
# 1       S102        Sneha   Hadapsar  Data Science     2026-01-12     Priya
# 6       S107        Rahul  Chinchwad  Data Science     2026-01-25      Amit
# 9       S110     Priyanka   Hadapsar  Data Science     2026-02-08     Priya
#
#    Total_Fees  Paid_Fees Payment_Mode  Remaining_Fees Payment_Status
# 1       50000      50000         Cash               0     Fully Paid
# 6       50000      30000         Card           20000        Pending
# 9       50000      35000          UPI           15000        Pending

# %%
admission_df[admission_df["Branch"]=="Chinchwad"]
# Out:
#    Student_ID Student_Name     Branch          Course Admission_Date  \
# 0        S101         Amit  Chinchwad  Data Analytics     2026-01-10
# 3        S104        Pooja  Chinchwad  Data Analytics     2026-01-18
# 6        S107        Rahul  Chinchwad    Data Science     2026-01-25
# 10       S111      Vaibhav  Chinchwad  Data Analytics     2026-02-10
#
#    Counselor  Total_Fees  Paid_Fees Payment_Mode  Remaining_Fees  \
# 0      Rahul       40000      30000          UPI           10000
# 3      Rahul       40000      40000         Card               0
# 6       Amit       50000      30000         Card           20000
# 10     Rahul       40000      20000          UPI           20000
#
#    Payment_Status
# 0         Pending
# 3      Fully Paid
# 6         Pending
# 10        Pending

# %%
admission_df[admission_df["Payment_Status"]=="Pending"]
# Out:
#    Student_ID Student_Name       Branch             Course Admission_Date  \
# 0        S101         Amit    Chinchwad     Data Analytics     2026-01-10
# 2        S103        Rohit  Karve Nagar  Python Full Stack     2026-01-15
# 4        S105        Akash       Nagpur    Java Full Stack     2026-01-20
# 6        S107        Rahul    Chinchwad       Data Science     2026-01-25
# 8        S109        Kunal       Nagpur     Data Analytics     2026-02-05
# 9        S110     Priyanka     Hadapsar       Data Science     2026-02-08
# 10       S111      Vaibhav    Chinchwad     Data Analytics     2026-02-10
#
#    Counselor  Total_Fees  Paid_Fees Payment_Mode  Remaining_Fees  \
# 0      Rahul       40000      30000          UPI           10000
# 2       Amit       30000      20000          UPI           10000
# 4       Neha       30000      15000          UPI           15000
# 6       Amit       50000      30000         Card           20000
# ...
